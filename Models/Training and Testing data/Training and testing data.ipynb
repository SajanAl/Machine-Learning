# %% [markdown]
# # Training and testing data

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
pd.read_csv('D:\Data\carprices.csv')
# Out:
#     Mileage  Sell Price($)  Age(yrs)
# 0     69000          18000         6
# 1     35000          34000         3
# 2     57000          26100         5
# 3     22500          40000         2
# 4     46000          31500         4
# 5     59000          29400         5
# 6     52000          32000         5
# 7     72000          19300         6
# 8     91000          12000         8
# 9     67000          22000         6
# 10    83000          20000         7
# 11    79000          21000         7
# 12    59000          33000         5

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'],color='red')

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color='green')

# %%
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
X=df[['Mileage','Age(yrs)']]
X.head(5)
# Out:
#    Mileage  Age(yrs)
# 0    69000         6
# 1    35000         3
# 2    57000         5
# 3    22500         2
# 4    46000         4

# %%
Y=df['Sell Price($)']
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %% [markdown]
# # Use train test spilit from sklear

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2) #,random_state=10) random function hold the changing data

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 10    83000         7
# 4     46000         4
# 8     91000         8
# 12    59000         5
# 13    58780         4
# 11    79000         7
# 14    82450         7
# 17    69000         5
# 18    87600         8
# 19    52000         5
# 3     22500         2
# 0     69000         6
# 15    25400         3
# 9     67000         6
# 16    28000         2

# %%
reg=linear_model.LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#    Mileage  Age(yrs)
# 7    72000         6
# 1    35000         3
# 5    59000         5
# 2    57000         5

# %%
reg.predict(X_test)
# Out:
# array([27814.09551917, 13482.41219836, 16713.57717804, 25382.08662986])

# %%
reg.score(X_test,Y_test)
# Out:
# 0.9377494197201958
